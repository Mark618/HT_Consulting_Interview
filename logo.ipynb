# %%
# !git clone https://github.com/ultralytics/yolov5
# Out:
# Cloning into 'yolov5'...
# remote: Enumerating objects: 15637, done.
# remote: Counting objects: 100% (244/244), done.
# remote: Compressing objects: 100% (143/143), done.
# remote: Total 15637 (delta 123), reused 173 (delta 101), pack-reused 15393
# Receiving objects: 100% (15637/15637), 14.65 MiB | 18.47 MiB/s, done.
# Resolving deltas: 100% (10647/10647), done.

# %%
cd yolov5
# Out:
# /content/yolov5

# %%
# !pip install -r requirements.txt

# %%
cp -r /content/drive/MyDrive/TRY/HT\ Consultant/logo/ .

# %%
# !python train.py --img 640 --batch 12 --epochs 10 --data /content/yolov5/data/coco128.yaml --weights yolov5s.pt --cache --freeze 10
# Out:
# train: weights=yolov5s.pt, cfg=, data=/content/yolov5/data/coco128.yaml, hyp=data/hyps/hyp.scratch-low.yaml, epochs=10, batch_size=12, imgsz=640, rect=False, resume=False, nosave=False, noval=False, noautoanchor=False, noplots=False, evolve=None, bucket=, cache=ram, image_weights=False, device=, multi_scale=False, single_cls=False, optimizer=SGD, sync_bn=False, workers=8, project=runs/train, name=exp, exist_ok=False, quad=False, cos_lr=False, label_smoothing=0.0, patience=100, freeze=[10], save_period=-1, seed=0, local_rank=-1, entity=None, upload_dataset=False, bbox_interval=-1, artifact_alias=latest
# github: up to date with https://github.com/ultralytics/yolov5 ✅
# requirements: /content/requirements.txt not found, check failed.
# YOLOv5 🚀 v7.0-162-gc3e4e94 Python-3.10.11 torch-2.0.0+cu118 CPU
#
# ...

# %%
# !python detect.py --weights runs/train/exp3/weights/best.pt --img 640 --conf 0.1 --source /content/image
# Out:
# detect: weights=['runs/train/exp3/weights/best.pt'], source=/content/image, data=data/coco128.yaml, imgsz=[640, 640], conf_thres=0.1, iou_thres=0.45, max_det=1000, device=, view_img=False, save_txt=False, save_conf=False, save_crop=False, nosave=False, classes=None, agnostic_nms=False, augment=False, visualize=False, update=False, project=runs/detect, name=exp, exist_ok=False, line_thickness=3, hide_labels=False, hide_conf=False, half=False, dnn=False, vid_stride=1
# requirements: /content/requirements.txt not found, check failed.
# YOLOv5 🚀 v7.0-162-gc3e4e94 Python-3.10.11 torch-2.0.0+cu118 CPU
#
# Fusing layers...
# Model summary: 157 layers, 7012822 parameters, 0 gradients, 15.8 GFLOPs
# image 1/3 /content/image/sample_1.jpg: 352x640 (no detections), 209.6ms
# image 2/3 /content/image/sample_2.jpg: 288x640 (no detections), 156.8ms
# image 3/3 /content/image/sample_3.jpg: 320x640 1 Logo, 209.0ms
# ...

# %%
import glob
from IPython.display import Image, display

for imageName in glob.glob('/content/yolov5/runs/detect/exp2/*'): #assuming JPG
    display(Image(filename=imageName))
    print("\n")
